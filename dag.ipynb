# %%
library(dplyr)
library(ggplot2)
library(dagitty)

# %%
# make a dag
dag = dagitty("dag {
Host -> GDP
Exchange-rate -> Host
Trade-percentage -> Exchange-rate
Exports -> Trade-percentage
Exports -> Host
Exports -> Exchange-rate
Population -> Host
Tourism-expenditures -> Host
Adjusted-National-Income -> Host
Urban-population-percentage -> Host
Unemployment -> Host
Labor-force -> Host
National-expenditures -> Host
CFP -> Host
Capital Formulation -> CFP
Umemployment -> CPI
Urban-population -> Urban-population-percentage
Population -> GDP
Exports -> GDP
Tourism-expenditures -> GDP
Adjusted-National-Income -> GDP
Urban-population-percentage -> GDP
CPI -> GDP
Labor-force -> GDP
National-expenditures -> GDP
CFP -> GDP}")

# plot the dag
plot(dag)
# Out:
# Plot coordinates for graph not supplied! Generating coordinates, see ?coordinates for how to set your own.
# plot without title
